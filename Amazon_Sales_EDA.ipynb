# %% [markdown]
# #EDA Project on Amazon sales report...

# %% [markdown]
# #**OBSERVATION**:
#
# This is my Amazon sales report for this EDA project have taken the Row dataset from the online websits this dataset contain 21 columns and 128976 rows which contain null values and duplicates.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # To supress warnings
sns.set(style="whitegrid") # set the background for the graphs

# %% [markdown]
# i have imported the libraries to perform process of cleaning and modifying and shaping and normalizing the data it also help for nutralizing the data.

# %% [markdown]
# Data collection:
# Here i have used the csv file as a dataset we can use it by using read_csv()

# %%
from google.colab import drive
# drive.mount('/content/drive')

# %%
data=pd.read_csv('/content/drive/MyDrive/Dataset/Amazon Sale Report-checkpoint.csv') #hear we are taking our data from csv file present in drive.

# %% [markdown]
# Data **Inspection** : i'm using pandas methods to inspection
#
# **Pandas Methods to Use**:
# #pd.read_csv() - Load the dataset.
# #head() - View the first few rows of the data.
# #info() - Understand the structure of the data, data types, and missing values.
# #describe() - Get summary statistics for numerical columns.
# #shape - Check the number of rows and columns.
# #columns - List the column names.

# %% [markdown]
# in my data total 21 columns are present every column is contaian a different type of data

# %%
data.columns #By using this command we can display our columns and my data contain 21 columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
data.head(5) #By using this head() we can display the first 5 rows you can see it below
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
data.tail(5) #by using this tail() we can displaying the last 5 rows in my table you can noices the index numbers for better understanding
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128971  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128972  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128973  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128974  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128975  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  ...  \
# 128971     Amazon.in          Expedited    Shirt   XL        Shipped  ...
# 128972     Amazon.in          Expedited  T-shirt    M        Shipped  ...
# 128973     Amazon.in          Expedited  Blazzer  XXL        Shipped  ...
# 128974     Amazon.in          Expedited  T-shirt   XS        Shipped  ...
# 128975     Amazon.in          Expedited  T-shirt    S        Shipped  ...
#
#         currency  Amount  ship-city    ship-state ship-postal-code  \
# ...

# %%
data.info() #this .info() used to display the information of entire table.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %% [markdown]
# The info() helps to understand the data easily and use it for perform the forther process by observing the info i can understand that my data contain the 21 columns and 4 datatypes like(Bool,Float,int64,Object) and my data using the memory(19.8 MB).

# %%
data.shape #this shape methoed used to understand the shape of table.
# Out:
# (128976, 21)

# %%
data.describe() # This describe() will help to identify the numberical data and it will performs Statistics like mean,std,min,max...
# Out:
#                index            Qty         Amount  ship-postal-code  New  \
# count  128976.000000  128976.000000  121176.000000     128941.000000  0.0
# mean    64486.130427       0.904401     648.562176     463945.677744  NaN
# std     37232.897832       0.313368     281.185041     191458.488954  NaN
# min         0.000000       0.000000       0.000000     110001.000000  NaN
# 25%     32242.750000       1.000000     449.000000     382421.000000  NaN
# 50%     64486.500000       1.000000     605.000000     500033.000000  NaN
# 75%     96730.250000       1.000000     788.000000     600024.000000  NaN
# max    128974.000000      15.000000    5584.000000     989898.000000  NaN
#
#        PendingS
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
datatype=data.dtypes   #This dtypes method help for identify the different datatypes in data
datatype
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Category               object
# Size                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# B2B                      bool
# fulfilled-by           object
# New                   float64
# PendingS              float64
# dtype: object

# %% [markdown]
#  Data Cleaning
#
# **Pandas Methods to Use:** **bold text**
#
# .isnull().sum() - Identify missing values in each column.
# .dropna() or .fillna() - Handle missing values appropriately.
# .duplicated() and .drop_duplicates() - Check and remove duplicates if any.
# .astype() - Convert columns to appropriate data types if necessary.
# Handle outliers if needed:
# .quantile() for detecting outliers using IQR.
# .clip() to handle extreme values.
# Justification: Ensures the dataset is clean, consistent, and ready for analysis by addressing missing or erroneous data points.

# %%
data.isnull().sum() #This function helps to identify the null values in a table
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %% [markdown]
# By Using isnull().sum() i came to know that mydata contain some null values and some missing values..

# %%
data.fillna(0,inplace=True) #it help to fill the null values with value ="0"

# %%
data.isnull().sum() #We use the same command to check whether all null values are removed are not.Now i cann't see any null values in my data.
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# New                   0
# PendingS              0
# dtype: int64

# %%
data.drop('New',axis=1,inplace=True)          #this two coulmns will not contain any data so we can delete for better analysis .
data.drop('PendingS',axis=1,inplace=True)      #we are using drop() to remove that two coulmns

# %%
data.info() #Here we are cross-checking the data information to check if any null value is still present in data
            #Or Data is now not have any Null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            128976 non-null  object
#  12  Amount              128976 non-null  float64
#  13  ship-city           128976 non-null  object
#  14  ship-state          128976 non-null  object
# ...

# %%
data.duplicated().sum() # this function used to check dupicated values
# Out:
# np.int64(168)

# %% [markdown]
# MyData contain 168 duplicated values.  We have to remove it.
#
# ---

# %%
da= data.drop_duplicates() #we are using the drop_duplicates() to remove duplicates
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128808 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128808 non-null  int64
#  1   Order ID            128808 non-null  object
#  2   Date                128808 non-null  object
#  3   Status              128808 non-null  object
#  4   Fulfilment          128808 non-null  object
#  5   Sales Channel       128808 non-null  object
#  6   ship-service-level  128808 non-null  object
#  7   Category            128808 non-null  object
#  8   Size                128808 non-null  object
#  9   Courier Status      128808 non-null  object
#  10  Qty                 128808 non-null  int64
#  11  currency            128808 non-null  object
#  12  Amount              128808 non-null  float64
#  13  ship-city           128808 non-null  object
#  14  ship-state          128808 non-null  object
# ...

# %%
data.duplicated().sum() # Now we can see that duplicates has been removed from our data
# Out:
# np.int64(168)

# %%
data.rename(columns={'ship-city':'ship_city'},inplace=True) # Here we are using the replace() for replace the column names
data.rename(columns={'ship-state':'ship_state'},inplace=True)

# %%
data.ship_city=data['ship_city'].astype('string')     #Here we are using the astype() to change the datatype into other Datatype
data.ship_state=data['ship_state'].astype('string')
data.Size=data['Size'].astype('category')
data.Category=data['Category'].astype('category')
data.B2B=data['B2B'].astype('category')
data.Status=data['Status'].astype('category')

# %%
data.info() # we using this info() again for cross check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  category
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  category
#  8   Size                128976 non-null  category
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            128976 non-null  object
#  12  Amount              128976 non-null  float64
#  13  ship_city           128976 non-null  string
#  14  ship_state          128976 non-null  string
# ...

# %%
data['currency']=data['currency'].fillna('INA') #here i have filling all blank vaiues of "currency" column with "INA"

# %%
data['currency'].isnull().sum()  #here we are conforming that we still have any null values are not
# Out:
# np.int64(0)

# %%
data['Amount']=data['Amount'].fillna(np.average(data['Amount'])) #filling null values with the avg('Amount')

# %%
data['Amount'].isnull().sum() #conforming the null values are removed are not
# Out:
# np.int64(0)

# %%
data['index'].duplicated().sum() #checking the duplicates in ['index']
# Out:
# np.int64(168)

# %%
dup=data[data['index'].duplicated(keep=False)] #confroming duplicates in 'index'
print(dup)
# Out:
#       index             Order ID      Date                        Status  \
# 6         6  408-5748499-6859555  04-30-22                       Shipped
# 7         7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8         8  407-5443024-5233168  04-30-22                     Cancelled
# 9         9  402-4393761-0311520  04-30-22                       Shipped
# 10       10  407-5633625-6970741  04-30-22                       Shipped
# ...     ...                  ...       ...                           ...
# 6640   6278  171-5170733-7855514  04-26-22  Shipped - Delivered to Buyer
# 6641   6279  403-8137343-5206760  04-26-22  Shipped - Delivered to Buyer
# 6642   6280  408-1575454-3263526  04-26-22  Shipped - Returned to Seller
# 6643   6281  171-2918708-7197155  04-26-22  Shipped - Delivered to Buyer
# 6644   6282  406-7244956-4740355  04-26-22                       Shipped
#
#      Fulfilment Sales Channel ship-service-level  Category Size  \
# ...

# %%
data.drop_duplicates(subset='index',keep='first',inplace=True) # here we are using the drop_duplicates() to remove the duplicates

# %%
data['index'].drop_duplicates().head() # we are printing the first 5 rows from data
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: index, dtype: int64

# %%
daa=data['index'].duplicated().sum()    #Checking the duplicates again to clarification.
print(daa)
# Out:
# 0

# %%
oho = data[~(data['ship_city']!='1')] # here we are using != to remove the ship_city ='1'
oho
# Out:
#          index             Order ID        Date   Status Fulfilment  \
# 113117  113116  404-8924840-1497908  06-11-2022  Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  Qty  \
# 113117     Amazon.in          Expedited    Shirt  XXL        Shipped    1
#
#        currency  Amount ship_city   ship_state  ship-postal-code ship-country  \
# 113117      INR   533.0         1  UTTARAKHAND          248001.0           IN
#
#           B2B fulfilled-by
# 113117  False            0

# %%
data =data[data['ship_city']!='1']        #we are removing outlayers to get perfect data
data =data[data['ship_state']!='0']
data =data[data['ship_state']!='APO']
data =data[data['ship_state']!='New Delhi']
data =data[data['ship_state']!='Delhi']
data =data[data['ship_state']!='delhi']

# %%
data['ship_city'].dtype  # to get datatype of "ship-city" by using dtype
# Out:
# string[python]

# %%
data['ship-postal-code'].duplicated().sum()  ##checking the duplicates in ['ship-postal-code'] column
# Out:
# np.int64(119055)

# %%
data['ship_city'].value_counts().head() # By using value_count() we are countimg the values repeting im data printing the first 5 rows
# Out:
# ship_city
# BENGALURU    11191
# HYDERABAD     8067
# MUMBAI        6115
# NEW DELHI     5774
# CHENNAI       5421
# Name: count, dtype: Int64

# %% [markdown]
# 1. What are the types of category?

# %%
data['Category'].nunique() #nuniqe() helps to find unique values but it show only number how many uniques are there
# Out:
# 9

# %%
data['Category'].unique() # by using the unique() we can show the unique vales in list formates
# Out:
# ['T-shirt', 'Shirt', 'Blazzer', 'Trousers', 'Perfume', 'Socks', 'Shoes', 'Wallet', 'Watch']
# Categories (9, object): ['Blazzer', 'Perfume', 'Shirt', 'Shoes', ..., 'T-shirt', 'Trousers', 'Wallet',
#                          'Watch']

# %% [markdown]
# in my ['category'] column i have observed that there are 9 unique values in mydataset.

# %% [markdown]
# 2. How many status types are there ?

# %%
data['Status'].unique() #Status- column contain 13 unique objects
# Out:
# ['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped', 'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer', ..., 'Shipped - Picked Up', 'Pending', 'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping']
# Length: 13
# Categories (13, object): ['Cancelled', 'Pending', 'Pending - Waiting for Pick Up', 'Shipped', ...,
#                           'Shipped - Rejected by Buyer', 'Shipped - Returned to Seller',
#                           'Shipped - Returning to Seller', 'Shipping']

# %% [markdown]
# 3. What are the types of sizes available ?

# %%
data['Size'].unique()  #in Size - column we contain the 11 unique values
# Out:
# ['S', '3XL', 'XL', 'L', 'XXL', ..., '6XL', 'M', '4XL', 'Free', '5XL']
# Length: 11
# Categories (11, object): ['3XL', '4XL', '5XL', '6XL', ..., 'S', 'XL', 'XS', 'XXL']

# %% [markdown]
# 4.How many B2B orders done?

# %%
print((data['B2B']==True).sum()) #hear we are using the sum() to sum the nO.of orders are done in B2B we have 869 orderd
# Out:
# 869

# %% [markdown]
# 5. What is the Higest order amount.

# %%
max(data['Amount']) #by usimg the max() we can find the max number are value form column "Amount"
# Out:
# 5584.0

# %% [markdown]
# 6. From how many citys we are getting ordres.

# %%
data['ship_city'].unique() # we have total 8918 unique values in "ship_city"
# Out:
# <StringArray>
# [                    'MUMBAI',                  'BENGALURU',
#                 'NAVI MUMBAI',                 'PUDUCHERRY',
#                     'CHENNAI',                  'GHAZIABAD',
#                  'CHANDIGARH',                  'HYDERABAD',
#                     'Chennai',                      'NOIDA',
#  ...
#                'Eroor  kochi',                'gandhinagar',
#  'MAMBAKKAM, CHINGLEPUT DIST',           'NEW DELHI 110032',
#       'Vaishali Nagar Nagpur',           'VARANASIVaranasi',
#            'Cherukunnu (p.o)',  'GULABPURA, Distt BHILWARA',
#       'Prayagraj (ALLAHABAD)',                      'Halol']
# Length: 8918, dtype: string

# %% [markdown]
# 7. From how many states we are getting ordres.

# %%
state_map = {                               #we are using  new variable to store the data
    'rajsthan': 'Rajasthan',
    'Rajsthan': 'Rajasthan',
    'Rajshthan': 'Rajasthan',
    'PB': 'Punjab',
    'punjab': 'Punjab',
    'Punjab/Mohali/Zirakpur': 'Punjab',
    'Orissa': 'Odisha',
    'orissa': 'Odisha',
    'Pondicherry': 'Puducherry',
    'goa': 'Goa',
    'Delhi': 'Delhi',
    'delhi': 'Delhi',
    'New Delhi': 'Delhi',
    'Arunachal pradesh': 'Arunachal Pradesh',
    'Arunachal Pradesh': 'Arunachal Pradesh',
    'NL': 'Nagaland',
    'bihar': 'Bihar',
    'Manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'Sikkim': 'Sikkim',
}

# %%
data['ship_state'] = data['ship_state'].replace(state_map) #here we replace the state_map to ship_state

# %%
data['ship_state'].unique() #checking the unique values from ship_state
# Out:
# <StringArray>
# [      'MAHARASHTRA',         'KARNATAKA',        'PUDUCHERRY',
#         'TAMIL NADU',     'UTTAR PRADESH',        'CHANDIGARH',
#          'TELANGANA',    'ANDHRA PRADESH',         'RAJASTHAN',
#              'DELHI',           'HARYANA',             'ASSAM',
#          'JHARKHAND',      'CHHATTISGARH',            'ODISHA',
#             'KERALA',    'MADHYA PRADESH',       'WEST BENGAL',
#           'NAGALAND',           'Gujarat',       'UTTARAKHAND',
#              'BIHAR',   'JAMMU & KASHMIR',            'PUNJAB',
#   'HIMACHAL PRADESH', 'ARUNACHAL PRADESH',               'Goa',
#          'MEGHALAYA',               'GOA',           'MANIPUR',
#            'TRIPURA',            'LADAKH',   'DADRA AND NAGAR',
#             'SIKKIM', 'ANDAMAN & NICOBAR',            'Punjab',
#          'Rajasthan',           'Manipur',         'rajasthan',
#             'Odisha',          'Nagaland',             'Bihar',
# ...

# %% [markdown]
# 8. From which city the more orders are palacing?

# %%
Max_city=data['ship_city'].value_counts().head() # the top citys which are placing the more and more orders are shown below
print(Max_city)
# Out:
# ship_city
# BENGALURU    11191
# HYDERABAD     8067
# MUMBAI        6115
# NEW DELHI     5774
# CHENNAI       5421
# Name: count, dtype: Int64

# %% [markdown]
# 9. Which size of T-shirts are sailing more ?

# %%
max_size=data['Size'].value_counts().head(5)  # by using this value_count() we can say that M size is sailed the most
print(max_size)
# Out:
# Size
# M      22300
# L      21727
# XL     20478
# XXL    17741
# S      16713
# Name: count, dtype: int64

# %% [markdown]
# 10. No.of orders repeted by same order id ?

# %%
data['Order ID'].duplicated().sum()  #checking the duplicates in Order ID the sum()
# Out:
# np.int64(8558)

# %%
data['Order ID'].value_counts().head() #checking and showing the top oarders repeted more than 10 times using same Order id
# Out:
# Order ID
# 403-4984515-8861958    12
# 171-5057375-2831560    12
# 404-9932919-6662730    11
# 403-0173977-3041148    11
# 408-3317403-1729937    10
# Name: count, dtype: int64

# %%
data['Order ID'].value_counts()[data['Order ID'].value_counts()>1]
#checking and showing the top oarders repeted more than 10 times using same Order id
# Out:
# Order ID
# 403-4984515-8861958    12
# 171-5057375-2831560    12
# 404-9932919-6662730    11
# 403-0173977-3041148    11
# 408-3317403-1729937    10
#                        ..
# 405-1319662-0902751     2
# 406-2843416-1416314     2
# 171-5302298-2221164     2
# 403-7731542-3716367     2
# 408-6831946-5261902     2
# Name: count, Length: 6814, dtype: int64

# %% [markdown]
# ## Univariate analyse on catagorical column
#
# category columns are - Status,Category,Size,B2B
#
# countplot(),histplot(),groupby(),values_count()
#
# Numarical columns are -Index,Qty,Amount,ship-postal-code
#
# countplot(),histplot(),boxplot(),kdeplot(),groupby(),value_counts()

# %%
data.describe()
#here we are using the describe() to get all numarical columns by using this it is easy to perform operations
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128508.000000  128508.000000  128508.000000     128508.000000
# mean    64564.640271       0.904426     609.454609     464684.700369
# std     37191.945388       0.313378     313.402278     190995.078144
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32374.750000       1.000000     413.000000     382480.000000
# 50%     64571.500000       1.000000     584.760000     500034.000000
# 75%     96768.250000       1.000000     771.000000     600027.250000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
data.info() #here we again using inf0() to check the all information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128508 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128508 non-null  int64
#  1   Order ID            128508 non-null  object
#  2   Date                128508 non-null  object
#  3   Status              128508 non-null  category
#  4   Fulfilment          128508 non-null  object
#  5   Sales Channel       128508 non-null  object
#  6   ship-service-level  128508 non-null  object
#  7   Category            128508 non-null  category
#  8   Size                128508 non-null  category
#  9   Courier Status      128508 non-null  object
#  10  Qty                 128508 non-null  int64
#  11  currency            128508 non-null  object
#  12  Amount              128508 non-null  float64
#  13  ship_city           128508 non-null  string
#  14  ship_state          128508 non-null  string
# ...

# %%
plt.figure(figsize=(8,5))           #figure() we use this to set the size of plot.
sns.countplot(y='Status',data=data) #here we are using the countplot to check the Status of orders it hlep for groth of bussiness
plt.title("Calculating the Status count")
plt.show()                          #we are showing the countplot().

# %% [markdown]
# By observing the countplot(). i can say that most of the orders are shipped in perfect time it helps to groth of bussiness.

# %%
data['Status'].value_counts().plot(kind='bar')
#value_counts() is helps for counting the values.we can use plot for easy understanding
# Out:
# <Axes: xlabel='Status'>

# %%
data.groupby('Status').size() #it will show the count of data in table form
# Out:
# Status
# Cancelled                        18269
# Pending                            657
# Pending - Waiting for Pick Up      281
# Shipped                          77523
# Shipped - Damaged                    1
# Shipped - Delivered to Buyer     28653
# Shipped - Lost in Transit            5
# Shipped - Out for Delivery          35
# Shipped - Picked Up                972
# Shipped - Rejected by Buyer         11
# Shipped - Returned to Seller      1948
# Shipped - Returning to Seller      145
# Shipping                             8
# dtype: int64

# %% [markdown]
# Category, Size        category
#
#  countplot,histplot,groupby,values_count()

# %%
sns.countplot(y='Category',data=data) #here we are using the countplot for understand the data of Category column
plt.title("Calculating the Category count")
plt.show()                          #we are showing the countplot().

# %%
data['Category'].value_counts().plot(kind='bar')
 #value_counts() is helps for counting the values.we can use plot for easy understanding
# Out:
# <Axes: xlabel='Category'>

# %%
data.groupby("Category").size()
#here we are finding the size of the category
# Out:
# Category
# Blazzer     15464
# Perfume      1153
# Shirt       49692
# Shoes         164
# Socks         439
# T-shirt     50101
# Trousers    10567
# Wallet        925
# Watch           3
# dtype: int64

# %% [markdown]
# Size
#
# countplot,histplot,groupby,values_count()

# %%
data.groupby("Size").size() #it helps to find the all sizes and how many members are orderd
# Out:
# Size
# 3XL     14588
# 4XL       425
# 5XL       549
# 6XL       738
# Free     2245
# L       21727
# M       22300
# S       16713
# XL      20478
# XS      11004
# XXL     17741
# dtype: int64

# %%
data["Size"].value_counts().plot(kind='bar')# it helps to undersatand the which size is sailing more.
# Out:
# <Axes: xlabel='Size'>

# %%
sns.countplot(y='Size',data=data) #another plot to understand sails of which is size
plt.title("Calculating the Size count")
plt.show()

# %%
sns.histplot(data=data,y='Size') #it show the flow of growth
plt.title("Calculating the Size count")
plt.show()

# %% [markdown]
# B2B
#
# countplot(),value_count()

# %%
data['B2B'].value_counts()
#here we are counting the B2B valie_count
# Out:
# B2B
# False    127639
# True        869
# Name: count, dtype: int64

# %%
sns.countplot(x='B2B',data=data) # here based on count values we are plotting the graph
plt.title("Calculating the B2B count")
plt.show()

# %% [markdown]
# ## univariate for numarical data
#
# Qty,Amount,Ship-postal-code

# %%
data.groupby('Qty').size() #here we are counting the.size of quality
# Out:
# Qty
# 0      12761
# 1     115361
# 2        339
# 3         32
# 4          9
# 5          2
# 8          1
# 9          1
# 13         1
# 15         1
# dtype: int64

# %%
data['Qty'].value_counts(normalize=True)*100
# here we are checking the value_count based on the  numeric values
# Out:
# Qty
# 1     89.769509
# 0      9.930121
# 2      0.263797
# 3      0.024901
# 4      0.007003
# 5      0.001556
# 9      0.000778
# 15     0.000778
# 13     0.000778
# 8      0.000778
# Name: proportion, dtype: float64

# %%
sns.histplot(data=data,x='Qty') # here we are calculating the count & Qty column for understanding the rows
plt.title("Calculating the Qty count")
plt.show()

# %%
sns.kdeplot(data=data,x='Qty')
#kdeplot helps to understands the the growth of Qty
plt.title("flow of the Qty density")
plt.show()

# %%
sns.boxplot(x='Qty',data=data)
# here we are using the boxplot to find the outliers
plt.title(" Qty outliers")
plt.show()

# %% [markdown]
# Amount

# %%
data.groupby('Amount').size()
# here we are checking size based on the amount.
# Out:
# Amount
# 0.00       10104
# 199.00         3
# 218.10         1
# 229.00        21
# 236.19         2
#            ...
# 2894.00        1
# 3036.00        1
# 4235.72        1
# 5495.00        1
# 5584.00        1
# Length: 1408, dtype: int64

# %%
data['Amount'].value_counts(normalize=True)*100
# calculating the amount will 100% numberic data
# Out:
# Amount
# 0.00       7.862546
# 399.00     4.212967
# 771.00     2.171071
# 735.00     1.894824
# 487.00     1.778878
#              ...
# 736.19     0.000778
# 1210.00    0.000778
# 505.71     0.000778
# 502.86     0.000778
# 796.20     0.000778
# Name: proportion, Length: 1408, dtype: float64

# %%
sns.histplot(data=data,x='Amount') # here we are using histplot for understand which amount products is sailing most
plt.title("Calculating the Amount flow")
plt.show()

# %%
sns.kdeplot(data=data,x='Amount') # by using histplot we can understand the data very quickly
plt.title("flow of the Amount density")
plt.show()

# %%
sns.boxplot(x='Amount',data=data)
# box plots are helpful to find outlaiers
plt.title("Amount outliers")
plt.show()

# %% [markdown]
# Ship-postal-code

# %%
data.groupby('ship-postal-code').size()
# we are using this groupby() and size() for get the size of each code
# Out:
# ship-postal-code
# 110001.0    47
# 110002.0    40
# 110003.0    60
# 110004.0     1
# 110005.0    68
#             ..
# 855115.0     2
# 855116.0     2
# 855117.0     2
# 984196.0     1
# 989898.0     1
# Length: 9453, dtype: int64

# %%
data['ship-postal-code'].value_counts(normalize=True)*100
# here we are neutralizeing the postal-codes
# Out:
# ship-postal-code
# 201301.0    0.782831
# 122001.0    0.533819
# 560037.0    0.491798
# 560068.0    0.477013
# 560076.0    0.451334
#               ...
# 632010.0    0.000778
# 441908.0    0.000778
# 364060.0    0.000778
# 673581.0    0.000778
# 209821.0    0.000778
# Name: proportion, Length: 9453, dtype: float64

# %%
sns.histplot(data=data,x='ship-postal-code')
# we are representing the ship-postal-code in histogram to understand quickly
plt.title("Calculating the ship-postal-code flow")
plt.show()

# %%
#sns.countplot(x='ship-postal-code',data=data)

# %%
sns.kdeplot(data=data,x='ship-postal-code')
#here we are using the kdeplot to understand the flow of ship-postal-code data
plt.title("flow of the ship-postal-code density")
plt.show()

# %%
sns.boxplot(x='ship-postal-code',data=data)
# here we are using boxplot for finding the outliers
plt.title("ship-postal-code outliers")
plt.show()

# %% [markdown]
# biVARIATE

# %%
data.groupby('Status')['ship-postal-code'].value_counts(normalize=True)*100
#BIVARIANTE here we are grouping the status and ship-postal-code column to get the refine data
# Out:
# Status     ship-postal-code
# Cancelled  201301.0            0.722535
#            560037.0            0.465269
#            500072.0            0.459795
#            122001.0            0.416005
#            560068.0            0.405058
#                                  ...
# Shipping   855115.0            0.000000
#            855116.0            0.000000
#            855117.0            0.000000
#            984196.0            0.000000
#            989898.0            0.000000
# Name: proportion, Length: 122889, dtype: float64

# %%
sns.barplot(hue='Status',x='ship-postal-code',data=data)
# Out:
# <Axes: xlabel='ship-postal-code'>

# %%
sns.barplot(x='B2B',y='Status', data=data)
# here we are ploting the graph btw B2B and Status
plt.title("B2B vs Status")
plt.show()

# %%
sns.scatterplot(x='Qty',y='Amount',data=data)
# here we are using the scattereplot for checking the how many members ordering the which amount of poroduct is ordering most
plt.title("Qty vs Amount")
plt.show()

# %%
sns.scatterplot(x='Qty',y='ship-postal-code',data=data)
#this scatterplot is between the Qty and Ship-postal-code we can see thet more order quantiy is 1 are 2
plt.title("Qty vs ship-postal-code")
plt.show()

# %%
sns.boxplot(y='Status',x='Amount',data=data)
#it helps for understand in which amount range orders are cancelled we observed that btw 1500 to 2000 amount we are getting cancelled orders
plt.title("Status vs Amount")
plt.show()

# %%
sns.displot(data=data,x='Size',hue='Status')
#by using this displot we can see the status of size to improve sails
plt.title("Size vs Status")
plt.show()

# %%
sns.displot(data=data,y='Category',hue='Status')
#here we are seeing the Status of products to undersand which product is sailing more and which product is not sailing
plt.title("Category vs Status")
plt.show()

# %%
data.groupby('Qty')['Amount'].mean()
# we can observe the mean of Each Qty based on amount
# Out:
# Qty
# 0      248.999996
# 1      647.140481
# 2     1198.908555
# 3     1558.218750
# 4     1998.222222
# 5     3835.000000
# 8     5584.000000
# 9        0.000000
# 13       0.000000
# 15       0.000000
# Name: Amount, dtype: float64

# %%
sns.violinplot(data=data,y='Status',x='Amount')
#by unsig violinplot we can easily track the on which amount of product status
plt.title("Status vs Amount")
plt.show()

# %%
Ram=pd.crosstab(data['Status'],data['Category'])  #here we are cross checking the order status based on catagory
Ram
# Out:
# Category                       Blazzer  Perfume  Shirt  Shoes  Socks  T-shirt  \
# Status
# Cancelled                         2118      144   7229     21     59     7310
# Pending                             92        7    247      0      1      252
# Pending - Waiting for Pick Up       79        0     72      0      2      108
# Shipped                           7460      754  30695    119    222    30547
# Shipped - Damaged                    1        0      0      0      0        0
# Shipped - Delivered to Buyer      5178      230  10395     22    139    10609
# Shipped - Lost in Transit            1        0      2      0      0        2
# Shipped - Out for Delivery           6        0      5      0      0       19
# Shipped - Picked Up                186        2    297      1     10      405
# Shipped - Rejected by Buyer          1        0      2      0      0        6
# Shipped - Returned to Seller       314       16    712      1      5      764
# ...

# %%
Ram.plot(kind='bar',stacked=True)  #we are ploting for the crossed data for understanding
plt.title("Status vs Category")
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.countplot(hue='Status',x='Category',data=data)  #we can see the status based category
plt.title("Status vs Category")
plt.show()

# %%
num_data=data[['Amount','Qty']]
num_data  #here we have taken two numarical columns for analysis
plt.figure(figsize=(10,5))
sns.heatmap(num_data.corr(),annot=True)
plt.title("Correlation of Amount and Qty")
plt.show()

# %% [markdown]
# 11.Which category of products are ordering most?

# %%
data['Category'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title("Category wise distribution")
plt.show()

# %% [markdown]
# We are using the pie plot for understand which item is ordering more and more. we observed that by pieplot we can see T-shirt-39%,Shirt 38.7%,wallet 0%,shoes 0%

# %%
sns.kdeplot(data=data,x='Amount',hue="Category",fill=True)
plt.title("Amount vs Category")
plt.show()

# %% [markdown]
# by using this kdeplot we can see that which item sales is improving rapidly and which are in low sales

# %% [markdown]
# For better understanding we are using pairplot now we can see the every type of combination based on ststus it hlep to improve sales

# %%
plt.figure(figsize=(10,5))
sns.pairplot(hue='Status',data=data)
plt.title("Pairplot")
plt.show()

# %% [markdown]
# #Conclusion:
# My EDA Project is helpfull for understand the amazon_sales_report and which product is ordering more and which prouct is not ordering and how many orders are canceling.This analysis is helpfull for increase sales by replacing items which are not saling and incresing the productivity of most liked products..
#
# #Thank's for listening :)
